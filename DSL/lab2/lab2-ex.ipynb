# %%
import pandas as pd
data = [['Dinesh',10],['Nithya',12],['Raji',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0  Dinesh   10
# 1  Nithya   12
# 2    Raji   13

# %%
data = {'Name':['Kavitha', 'Sudha', 'Raju','Vignesh'],'Age':[28,34,29,42]} 
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print(df)
# Out:
#           Name  Age
# rank1  Kavitha   28
# rank2    Sudha   34
# rank3     Raju   29
# rank4  Vignesh   42

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
print(df1)
df1.shape
# Out:
#            A  B       C
# 0 2013-01-02  3    Male
# 1 2013-01-02  3  Female
# 2 2013-01-02  3    Male
# 3 2013-01-02  3  Female
# (4, 3)

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
df1.dtypes
# Out:
# A    datetime64[s]
# B            int32
# C         category
# dtype: object

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
df.T
# Out:
#         rank1  rank2 rank3    rank4
# Name  Kavitha  Sudha  Raju  Vignesh
# Age        28     34    29       42

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.829059  0.567215 -0.520117  0.127068
# 2013-01-02  0.040021  0.934914  0.139204  0.615389
# 2013-01-03  0.522902 -1.469588 -1.368963 -0.504429
# 2013-01-04 -1.225698 -0.389246 -0.384865 -0.607825
# 2013-01-05 -1.574480  0.410135  0.780685  0.371713

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.tail()
# Out:
#                    A         B         C         D
# 2013-04-06 -0.110067 -0.156920  1.064066  0.257592
# 2013-04-07  0.267752  0.979701 -0.312383 -0.337076
# 2013-04-08  1.894520 -0.567437 -1.724518  0.455658
# 2013-04-09  0.670906 -1.388590 -0.260180  0.077533
# 2013-04-10  1.893178 -0.347400 -0.954014  0.160805

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01',
#                '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09',
#                '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13',
#                '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17',
#                '2013-02-18', '2013-02-19', '2013-02-20', '2013-02-21',
#                '2013-02-22', '2013-02-23', '2013-02-24', '2013-02-25',
#                '2013-02-26', '2013-02-27', '2013-02-28', '2013-03-01',
#                '2013-03-02', '2013-03-03', '2013-03-04', '2013-03-05',
#                '2013-03-06', '2013-03-07', '2013-03-08', '2013-03-09',
#                '2013-03-10', '2013-03-11', '2013-03-12', '2013-03-13',
#                '2013-03-14', '2013-03-15', '2013-03-16', '2013-03-17',
#                '2013-03-18', '2013-03-19', '2013-03-20', '2013-03-21',
#                '2013-03-22', '2013-03-23', '2013-03-24', '2013-03-25',
#                '2013-03-26', '2013-03-27', '2013-03-28', '2013-03-29',
#                '2013-03-30', '2013-03-31', '2013-04-01', '2013-04-02',
#                '2013-04-03', '2013-04-04', '2013-04-05', '2013-04-06',
#                '2013-04-07', '2013-04-08', '2013-04-09', '2013-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A    0.046244   -0.534002    2.425315    0.700724    0.109200    0.430003
# B    0.280024    0.592236    1.030711    0.332294   -0.489140    0.550454
# C    0.518102   -1.457779   -1.404272   -1.167191    0.346660   -0.202949
# D    1.215444   -0.272596    0.760412   -0.569265   -1.110046   -0.082400
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2013-04-01  \
# A    0.272662   -0.495762   -1.798691   -0.455158  ...   -0.554401
# B   -0.555825   -0.378714    1.651780   -0.233213  ...   -0.858246
# C    0.233212    0.655387   -1.708876    0.197848  ...   -1.253062
# D   -1.950524   -1.034514    0.869677   -1.254471  ...   -1.058570
#
#    2013-04-02  2013-04-03  2013-04-04  2013-04-05  2013-04-06  2013-04-07  \
# A    0.447803    0.316355   -0.930478    1.712297   -0.506430    0.549132
# B    1.059678   -1.905764    0.217975   -2.249450   -0.093403   -0.973446
# C    0.320244    0.982512   -1.374590   -1.025873   -0.278659   -0.514745
# D   -1.211528   -0.825938    0.419633   -0.363744    0.850830   -1.300071
#
#    2013-04-08  2013-04-09  2013-04-10
# A   -0.223209    1.361280   -1.560925
# B   -1.515089   -0.333857   -0.706808
# C    0.369224   -0.527856   -1.055694
# D   -0.085573   -0.301039    1.352606
#
# [4 rows x 100 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.478925 -1.656352 -1.291920 -2.028249
# 2013-01-02  0.759363  0.207475  0.048327  0.917661
# 2013-01-03  1.779671  0.055779  0.176404 -0.086303
# 2013-01-04  2.317824 -1.527673  0.640387 -0.683481
# 2013-01-05  1.370006 -0.893373  1.405876  0.981932
# ...              ...       ...       ...       ...
# 2013-04-06  0.424994 -0.490608  0.348274  1.553162
# 2013-04-07 -2.012976 -0.886279 -0.435681  1.082649
# 2013-04-08 -1.576086  0.361460 -1.492109 -0.337531
# 2013-04-09  0.014837 -0.539766 -1.262118 -1.176455
# 2013-04-10 -0.191406 -0.700648  0.452373 -0.626502
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-12  0.508683 -2.462439 -1.187920  1.001254
# 2013-01-21 -0.419018 -2.297331 -0.020650  0.172550
# 2013-02-20  0.707757 -2.199605  1.403894  0.246846
# 2013-01-14  0.055292 -2.113083  1.323370 -0.221199
# 2013-01-25 -0.606939 -1.956793 -0.234304  0.132115
# ...              ...       ...       ...       ...
# 2013-04-06 -0.351470  1.512953  1.052921  0.106342
# 2013-04-01  0.295814  1.550816 -0.840110  0.650682
# 2013-01-03  0.497724  1.912052 -1.981195 -0.174644
# 2013-03-26  0.070429  2.008026  2.649418 -0.629324
# 2013-03-08  1.120798  2.047233  1.062457  1.184643
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.977349 -1.214334  0.265017 -0.302482
# 2013-01-02  1.256833  0.092610  1.600506  1.522403
# 2013-01-03  1.096196 -0.145511 -0.242880 -0.595508

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df['20130105':'20130110']
# Out:
#                    A         B         C         D
# 2013-01-05  0.295381  0.714998 -0.069972  0.383007
# 2013-01-06  0.873456 -0.936566 -1.516215  0.628756
# 2013-01-07  0.186802  1.781063 -0.558313 -0.453486
# 2013-01-08 -1.923182  1.633909 -0.626887 -1.427881
# 2013-01-09 -0.131842 -2.227757 -1.211251 -0.792856
# 2013-01-10 -0.153371  0.990702  0.053143 -0.274590

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0]
# Out:
# A    0.678561
# B   -0.807726
# C   -0.765772
# D    0.136612
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0,:2]
# Out:
# A   -2.295082
# B    0.696042
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0,0]
# Out:
# -0.5342496466595359

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df['A']
# Out:
# 2013-01-01    0.936949
# 2013-01-02    0.737084
# 2013-01-03    1.668162
# 2013-01-04    0.881882
# 2013-01-05   -0.439815
#                 ...
# 2013-04-06    1.732552
# 2013-04-07   -1.218499
# 2013-04-08   -2.302292
# 2013-04-09    1.257253
# 2013-04-10   -2.237595
# Freq: D, Name: A, Length: 100, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.000814  0.175679
# 2013-01-02  0.792647 -0.302308
# 2013-01-03  0.193367  0.139235
# 2013-01-04  1.694136  0.750341
# 2013-01-05  0.045416  2.829174
# ...              ...       ...
# 2013-04-06  0.367881 -1.155376
# 2013-04-07 -0.365240 -0.697289
# 2013-04-08  0.417038 -0.394693
# 2013-04-09 -0.132084 -0.238511
# 2013-04-10  0.644547  1.248389
#
# [100 rows x 2 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[['A','B']][:5]
# Out:
#                    A         B
# 2013-01-01 -0.195706 -0.264182
# 2013-01-02 -1.612499 -0.444644
# 2013-01-03  0.354747  0.400381
# 2013-01-04  1.516513 -1.437474
# 2013-01-05 -0.549991  2.328467

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.loc['20130101':'20130105',['A','B']][:5]
# Out:
#                    A         B
# 2013-01-01  1.445391 -1.364491
# 2013-01-02 -0.664904  0.159019
# 2013-01-03  0.353174 -0.876116
# 2013-01-04 -0.638588 -1.191859
# 2013-01-05 -0.928136  1.139907

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[df.A>0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.563700  0.482866  0.373788 -0.089007
# 2013-01-03  0.149501 -0.607252  0.475661 -0.225792
# 2013-01-04  0.593508  1.435733 -0.425921 -0.040068
# 2013-01-05  0.357225  0.799965 -1.695913 -1.853580
# 2013-01-06  0.048900 -0.576239  1.381695 -0.941756
# 2013-01-09  0.452776  1.056757 -0.646133 -0.158922
# 2013-01-10  1.067968 -1.236861  0.226244  0.905566
# 2013-01-11  1.437001  0.194749 -0.260127 -1.143650
# 2013-01-16  1.538715  0.405304 -0.514167  1.051784
# 2013-01-19  1.020504 -0.016409  0.038570  1.328337
# 2013-01-20  0.430338  0.209509  0.069458  2.857647
# 2013-01-22  0.613589 -0.527621  1.147403 -1.350399
# 2013-01-23  1.894374  0.368259 -1.148525  0.149367
# 2013-01-25  0.811394 -2.065957  0.666967  1.470413
# 2013-01-26  0.255994 -1.968473 -0.821495 -0.714880
# 2013-01-30  0.769431 -0.207232  0.821169 -0.041260
# 2013-01-31  1.537415  0.220593  0.894350 -0.037975
# 2013-02-01  0.598801 -0.823748 -1.427550 -0.476894
# 2013-02-02  0.770931 -0.839136 -0.481307 -0.266344
# 2013-02-05  0.652452 -0.371589  1.063171 -0.333564
# 2013-02-06  0.895372  0.779343  1.654691  0.384209
# 2013-02-07  0.315202 -1.124135 -1.679820  1.486224
# 2013-02-08  0.756681 -0.753308 -1.860330  1.417198
# 2013-02-10  0.881443 -1.628367  0.020020  0.928283
# 2013-02-13  0.689223  0.361977 -1.614069 -0.013741
# 2013-02-16  0.550561  0.249304 -0.119618  0.811091
# 2013-02-20  2.008425  0.346836  1.301332  0.662329
# 2013-02-22  0.799822  0.372859  0.143966 -1.396393
# 2013-02-25  0.929301  0.480352 -0.296965  0.111539
# 2013-02-26  1.028430  0.654262  1.655861  0.412915
# 2013-02-28  0.525104 -0.587405 -1.941206 -0.390267
# 2013-03-02  0.224315  0.612129  0.666216 -1.353272
# 2013-03-04  1.021980  1.615536 -0.564831 -0.168141
# 2013-03-05  0.700558  2.239759 -0.226132  0.139832
# 2013-03-08  0.097802 -1.151401 -1.485007  0.013198
# 2013-03-10  2.326419  1.471649  1.651538  1.620991
# 2013-03-12  0.374867  0.114513  0.329139  1.214869
# 2013-03-13  0.127745  2.689439 -1.679779 -0.823582
# 2013-03-15  0.835462 -0.311328  1.076052 -1.198504
# 2013-03-18  0.163599  0.557831  1.311270 -0.510237
# 2013-03-20  0.171781  0.957325 -1.979696 -0.589483
# 2013-03-21  1.193846  0.566490 -0.599483 -0.397826
# 2013-03-22  0.277786  0.736228 -0.614905  1.131922
# 2013-03-23  0.017862 -0.763280  0.565243 -0.566792
# 2013-03-24  1.760448 -1.352067  0.284523 -1.520017
# 2013-03-27  0.200379 -0.916759 -0.349103  0.150569
# 2013-03-28  0.139048 -0.256947  0.520325 -0.930364
# 2013-03-30  0.816787 -0.652496 -0.423668 -0.711819
# 2013-04-04  2.444464  0.020217  0.551623 -0.746862
# 2013-04-06  1.176782 -0.475825  0.543337  0.129951
# 2013-04-07  0.658666 -1.290186  1.608034  0.032291

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
gender_labels = np.random.choice(['Male', 'Female'], size=100)
df['F'] = gender_labels
print(df)
# Out:
#                    A         B         C         D       F
# 2013-01-01  1.002285  0.758347 -0.619127 -0.211114    Male
# 2013-01-02  2.212060  0.623455  0.738998 -0.990020  Female
# 2013-01-03  0.433864 -0.856741  0.562849  1.501408  Female
# 2013-01-04 -1.223163  0.021088  0.195672 -0.214195  Female
# 2013-01-05  1.261847  0.225130  0.991687 -0.055244  Female
# ...              ...       ...       ...       ...     ...
# 2013-04-06 -0.009746 -0.252452 -1.181200  0.053989    Male
# 2013-04-07  0.041272  1.139605  0.270646 -0.489861    Male
# 2013-04-08  1.861632  0.369453  0.826103  0.474796    Male
# 2013-04-09  1.916226  0.764126 -0.630548 -0.792019    Male
# 2013-04-10  0.287200 -0.963423  1.449006  0.665608    Male
#
# [100 rows x 5 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.loc[:,'D']=np.array([5]*len(df))
print(df)
# Out:
#                    A         B         C    D
# 2013-01-01  0.003733 -0.999695  0.352913  5.0
# 2013-01-02  0.801423 -0.287022  1.007014  5.0
# 2013-01-03 -0.366306 -0.544800 -0.136264  5.0
# 2013-01-04  1.950981 -1.176286 -1.336093  5.0
# 2013-01-05  1.569776 -0.765026 -1.460949  5.0
# ...              ...       ...       ...  ...
# 2013-04-06  1.241124 -0.780157 -0.442254  5.0
# 2013-04-07 -2.588437  0.297681 -0.221810  5.0
# 2013-04-08 -0.136647 -0.454406 -0.381052  5.0
# 2013-04-09  0.017507  0.298178 -0.330812  5.0
# 2013-04-10  1.083394  0.494287 -1.150175  5.0
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.drop('A', axis =1, inplace=True)
print(df)
# Out:
#                    B         C         D
# 2013-01-01  1.167774  0.669687 -1.950014
# 2013-01-02  0.714066  0.114970  2.718256
# 2013-01-03  0.971117  1.204299 -2.102792
# 2013-01-04 -0.485927  2.257203  1.532987
# 2013-01-05  1.601337  0.969514 -1.289433
# ...              ...       ...       ...
# 2013-04-06 -0.935308 -1.825609  0.235138
# 2013-04-07 -1.379526  2.270713  0.506099
# 2013-04-08  0.470703  0.935190 -0.820710
# 2013-04-09  0.504982 -0.313037  1.203651
# 2013-04-10  0.258337 -0.687777  0.325881
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
 
df = pd.DataFrame({'Courses': ["GFG", "JS", "Python", "Numpy"],
                   'Fee': [20000, 25000, 22000, 24000]})
 
df1 = pd.DataFrame({'Courses': ["Matplotlib", "SSC", "CHSL", "Java"],
                    'Fee': [25000, 25200, 24500, 24900]})
 
df2 = pd.DataFrame({'Duration': ['30day', '40days', '35days', '60days'],
                    'Discount': [1000, 2300, 2500, 2000]})

# concatenating df1 and df2 along rows
vertical_concat = pd.concat([df, df1], axis=0)
 
# concatenating df3 and df4 along columns
horizontal_concat = pd.concat([df1, df2], axis=1)
 
print("Vertical:")
print(vertical_concat)
print("Horizontal:")
print(horizontal_concat)

#sorting and ordering a dataframe
df.sort_values(by='Fee')
# Out:
# Vertical:
#       Courses    Fee
# 0         GFG  20000
# 1          JS  25000
# 2      Python  22000
# 3       Numpy  24000
# 0  Matplotlib  25000
# 1         SSC  25200
# 2        CHSL  24500
# 3        Java  24900
# Horizontal:
#       Courses    Fee Duration  Discount
# 0  Matplotlib  25000    30day      1000
# 1         SSC  25200   40days      2300
# 2        CHSL  24500   35days      2500
# 3        Java  24900   60days      2000
#   Courses    Fee
# 0     GFG  20000
# 2  Python  22000
# 3   Numpy  24000
# 1      JS  25000

# %%
df = pd.read_csv('xyz.csv',header=None)
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
df = pd.read_csv('xyz.csv',header=None)
df.tail()
# Out:
#       0    1   2   3    4     5      6   7  8
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %%
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
print(df)
# Out:
#      preg  glu  bp  sft  ins   bmi    dpf  age  class
# 0       6  148  72   35    0  33.6  0.627   50      1
# 1       1   85  66   29    0  26.6  0.351   31      0
# 2       8  183  64    0    0  23.3  0.672   32      1
# 3       1   89  66   23   94  28.1  0.167   21      0
# 4       0  137  40   35  168  43.1  2.288   33      1
# ..    ...  ...  ..  ...  ...   ...    ...  ...    ...
# 763    10  101  76   48  180  32.9  0.171   63      0
# 764     2  122  70   27    0  36.8  0.340   27      0
# 765     5  121  72   23  112  26.2  0.245   30      0
# 766     1  126  60    0    0  30.1  0.349   47      1
# 767     1   93  70   31    0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
import matplotlib.pyplot as plt 
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
plt.scatter(df['bmi'],df['glu'])
plt.xlabel('bmi') 
plt.ylabel('Glucose')
# Out:
# Text(0, 0.5, 'Glucose')

# %%
import matplotlib.pyplot as plt 
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
df['age'].hist()
# Out:
# <Axes: >

# %%
H = pd.read_table('HR.txt')
H.head() 
f=H['Department'].value_counts()
f
# Out:
# Department
# 2    961
# 1    446
# 3     63
# Name: count, dtype: int64

# %%
H = pd.read_table('HR.txt')
H.head() 
f.plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
H = pd.read_table('HR.txt')
H.head() 
f.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
H = pd.read_table('HR.txt')
H.head() 
fa=pd.crosstab(H['Gender'],H['Attrition']) 
fa.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>
