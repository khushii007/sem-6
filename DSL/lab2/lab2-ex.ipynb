# %%
import pandas as pd
data = [['Dinesh',10],['Nithya',12],['Raji',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0  Dinesh   10
# 1  Nithya   12
# 2    Raji   13

# %%
data = {'Name':['Kavitha', 'Sudha', 'Raju','Vignesh'],'Age':[28,34,29,42]} 
df = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print(df)
# Out:
#           Name  Age
# rank1  Kavitha   28
# rank2    Sudha   34
# rank3     Raju   29
# rank4  Vignesh   42

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
print(df1)
df1.shape
# Out:
#            A  B       C
# 0 2013-01-02  3    Male
# 1 2013-01-02  3  Female
# 2 2013-01-02  3    Male
# 3 2013-01-02  3  Female
# (4, 3)

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
df1.dtypes
# Out:
# A    datetime64[s]
# B            int32
# C         category
# dtype: object

# %%
import numpy as np
df1=pd.DataFrame({'A':pd.Timestamp('20130102'),'B':np.array([3]*4,dtype='int32'), 'C':pd.Categorical(['Male','Female','Male','Female'])})
df.T
# Out:
#         rank1  rank2 rank3    rank4
# Name  Kavitha  Sudha  Raju  Vignesh
# Age        28     34    29       42

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.642538  0.828281  0.497323  0.362911
# 2013-01-02 -1.126165  0.134438  0.861518 -1.387650
# 2013-01-03 -0.295029 -0.432799 -0.385298  1.218399
# 2013-01-04 -2.463984  0.078797 -0.417657 -0.383986
# 2013-01-05 -1.382863  1.036770 -1.265190 -0.896245

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.tail()
# Out:
#                    A         B         C         D
# 2013-04-06  0.111764 -1.964210  0.883998 -0.341716
# 2013-04-07  1.240680  1.620518 -0.491946  1.017879
# 2013-04-08 -0.912514 -0.380096  3.954786  1.548865
# 2013-04-09  0.729131 -1.903758 -1.412919  0.666579
# 2013-04-10  0.502272 -1.816542  0.811836 -1.017188

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01',
#                '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09',
#                '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13',
#                '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17',
#                '2013-02-18', '2013-02-19', '2013-02-20', '2013-02-21',
#                '2013-02-22', '2013-02-23', '2013-02-24', '2013-02-25',
#                '2013-02-26', '2013-02-27', '2013-02-28', '2013-03-01',
#                '2013-03-02', '2013-03-03', '2013-03-04', '2013-03-05',
#                '2013-03-06', '2013-03-07', '2013-03-08', '2013-03-09',
#                '2013-03-10', '2013-03-11', '2013-03-12', '2013-03-13',
#                '2013-03-14', '2013-03-15', '2013-03-16', '2013-03-17',
#                '2013-03-18', '2013-03-19', '2013-03-20', '2013-03-21',
#                '2013-03-22', '2013-03-23', '2013-03-24', '2013-03-25',
#                '2013-03-26', '2013-03-27', '2013-03-28', '2013-03-29',
#                '2013-03-30', '2013-03-31', '2013-04-01', '2013-04-02',
#                '2013-04-03', '2013-04-04', '2013-04-05', '2013-04-06',
#                '2013-04-07', '2013-04-08', '2013-04-09', '2013-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -0.301316   -0.868574    0.696176   -0.226674    0.312088    0.506517
# B    0.532154    1.563375   -0.411213    0.206854    0.225542    1.772277
# C   -1.565382   -0.774587   -0.741754    0.631696   -0.418059   -0.739405
# D   -1.042558    1.104674   -1.156162   -0.984768   -1.362163    2.073058
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2013-04-01  \
# A    0.212090    0.429221   -0.125792   -0.958773  ...    0.198345
# B   -0.248868    1.112226   -0.383698   -0.425216  ...   -0.737500
# C   -1.569665   -0.093589    0.790057   -0.570625  ...   -0.516731
# D   -0.362589    0.945405   -0.303361   -0.834183  ...   -0.444562
#
#    2013-04-02  2013-04-03  2013-04-04  2013-04-05  2013-04-06  2013-04-07  \
# A   -0.987678    2.170766    0.774395    0.048706   -0.683700    0.431976
# B    1.044430   -0.153775   -1.794998   -0.145537    0.333771    0.936919
# C    0.085635   -0.587318    1.119899    1.433505   -0.991123    1.220796
# D    0.482368    0.229997    0.128745    0.711645    0.459838    0.733592
#
#    2013-04-08  2013-04-09  2013-04-10
# A    0.959242   -0.370465    0.389054
# B   -1.306794   -0.027829    1.664594
# C    0.698531    0.834121   -1.367539
# D   -0.333543   -0.705633    0.140786
#
# [4 rows x 100 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.259533  0.936433  1.159165  1.516548
# 2013-01-02  0.704347 -0.464799 -1.424502 -0.101506
# 2013-01-03 -0.174337  1.679606  0.751232  0.082404
# 2013-01-04  0.993306 -0.088841 -3.039252  0.395807
# 2013-01-05 -0.297040  1.213180  0.109148 -0.741675
# ...              ...       ...       ...       ...
# 2013-04-06  1.381823 -1.337371 -0.371771 -0.653934
# 2013-04-07  1.062182 -0.683622  2.793751 -0.276865
# 2013-04-08 -0.497229  0.289063  0.847365  1.289278
# 2013-04-09 -0.005865 -0.384914  0.860150  1.366250
# 2013-04-10 -0.202154 -2.194635 -0.753523 -0.038677
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-02  0.538424 -2.562724 -0.794987  1.375925
# 2013-02-19  0.244895 -2.285509 -0.425765 -1.186281
# 2013-01-28 -0.505961 -2.274477  0.233113  0.082062
# 2013-03-29 -0.288486 -2.101183 -0.527478  0.689997
# 2013-02-03  0.494403 -1.773015  1.499877 -0.924764
# ...              ...       ...       ...       ...
# 2013-02-24  0.627692  1.872510  0.523569 -1.972685
# 2013-03-13 -0.533367  1.935073  1.336217  2.030007
# 2013-03-19  0.354524  1.984999  1.064633  1.569373
# 2013-04-01 -0.881445  2.229271  0.824149  2.411353
# 2013-01-03  0.493540  2.816699  0.223966 -0.793366
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.610508 -1.260237 -0.998415 -0.224458
# 2013-01-02 -0.183856  1.857781 -0.226902  0.066774
# 2013-01-03 -0.098676 -0.061911 -0.043239  0.534617

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df['20130105':'20130110']
# Out:
#                    A         B         C         D
# 2013-01-05  0.495061 -0.239882  1.451629  0.045447
# 2013-01-06 -0.012664  0.515089  0.545844  0.672032
# 2013-01-07 -0.103751  0.641384 -1.036060  0.117489
# 2013-01-08 -0.403070 -0.737625  0.267818  0.298866
# 2013-01-09 -0.721790  0.522995 -0.886656 -1.738390
# 2013-01-10  0.146636  0.053111 -0.802830  0.301445

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0]
# Out:
# A    1.308796
# B    0.002830
# C   -0.161657
# D    0.895640
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0,:2]
# Out:
# A    1.650151
# B   -0.478564
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.iloc[0,0]
# Out:
# 2.760434209117067

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df['A']
# Out:
# 2013-01-01    1.291592
# 2013-01-02    0.810442
# 2013-01-03    0.736505
# 2013-01-04   -0.185776
# 2013-01-05   -0.500861
#                 ...
# 2013-04-06   -0.728848
# 2013-04-07    2.156231
# 2013-04-08    0.845292
# 2013-04-09   -2.118156
# 2013-04-10   -0.862879
# Freq: D, Name: A, Length: 100, dtype: float64

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.058292  0.627069
# 2013-01-02  0.309820 -0.471291
# 2013-01-03  0.102423  0.316790
# 2013-01-04 -0.409723 -0.197516
# 2013-01-05  1.208064 -0.529341
# ...              ...       ...
# 2013-04-06 -0.287665 -1.041133
# 2013-04-07  2.750683 -0.386833
# 2013-04-08 -0.526345 -0.242569
# 2013-04-09 -0.935203  0.320377
# 2013-04-10 -0.905127 -1.093340
#
# [100 rows x 2 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[['A','B']][:5]
# Out:
#                    A         B
# 2013-01-01 -1.352134 -0.511335
# 2013-01-02 -0.978103  1.480345
# 2013-01-03 -1.216143  0.083113
# 2013-01-04  0.228843  0.983575
# 2013-01-05 -0.380095  0.582436

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.loc['20130101':'20130105',['A','B']][:5]
# Out:
#                    A         B
# 2013-01-01 -1.369996 -0.051631
# 2013-01-02 -0.115298 -0.236762
# 2013-01-03 -0.282392  0.477724
# 2013-01-04  0.606157 -1.190484
# 2013-01-05  1.960702  0.961825

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df[df.A>0]
# Out:
#                    A         B         C         D
# 2013-01-03  0.146541 -0.386929 -1.103832 -0.738391
# 2013-01-04  0.091430 -0.505062 -0.404591  0.739201
# 2013-01-05  0.782941 -0.027393  0.754297 -2.381708
# 2013-01-08  0.971308 -0.861455  1.119148  0.611111
# 2013-01-09  2.222109 -1.211058  1.385618  1.405364
# 2013-01-10  0.261412  0.267684  0.457280  0.636557
# 2013-01-11  1.481952  0.247477  0.072273 -0.243390
# 2013-01-13  0.021878 -0.971527 -0.525614 -0.976596
# 2013-01-14  0.764909  0.803407 -0.375547  1.212284
# 2013-01-16  0.125100  0.561661 -0.699605  0.113799
# 2013-01-19  0.977323  0.317780 -2.651045  0.942980
# 2013-01-22  0.820883  0.102329 -1.170171 -1.042250
# 2013-01-23  1.295239 -0.208597 -0.778962  0.261816
# 2013-01-25  0.123392  0.842590 -0.664048 -0.471160
# 2013-01-26  0.616973 -0.442528  0.459821 -0.417431
# 2013-01-27  1.242422  1.212121  0.213559 -0.723157
# 2013-01-29  0.323473 -1.629927 -0.122618 -2.279806
# 2013-02-01  0.099005  0.439496 -0.568300 -1.100593
# 2013-02-02  0.649219  0.555366 -0.059608 -1.733812
# 2013-02-03  1.486780  1.471658 -0.804408  0.801811
# 2013-02-04  1.252092 -0.653304 -1.681913 -1.267011
# 2013-02-05  1.073507 -1.016041  0.809274 -0.199351
# 2013-02-08  0.954194  0.391378  0.132659  1.391838
# 2013-02-09  0.512514  1.272318 -0.678295  0.058377
# 2013-02-10  1.021965 -0.516495  0.124517  0.521228
# 2013-02-11  1.297340 -0.979864  0.430607 -0.008558
# 2013-02-15  0.259834  0.122979  0.960005  1.974877
# 2013-02-19  0.109729 -0.474959  0.817033 -0.540622
# 2013-02-22  0.051834  1.389739  1.897088 -1.196762
# 2013-02-27  1.528289  1.077611 -0.229178 -0.662637
# 2013-03-01  0.334887 -0.288862  0.049167 -2.692287
# 2013-03-08  0.154004  0.910388 -0.527156  0.314597
# 2013-03-09  2.051023 -0.402007  0.262407  1.742713
# 2013-03-10  0.080316 -0.152498  0.414097  1.464612
# 2013-03-12  0.942452  0.257689 -0.570468  0.311754
# 2013-03-19  0.055159 -0.144640  0.111582 -2.120673
# 2013-03-25  0.018452 -1.796142 -0.007117  0.363917
# 2013-03-30  0.057464  0.088766 -1.405684 -1.410128
# 2013-04-01  0.602887  0.620582  2.016093 -1.085348
# 2013-04-03  0.187787 -1.371692  1.160112 -1.709640
# 2013-04-06  0.598228 -0.790539 -0.064261 -0.632255
# 2013-04-07  0.388134 -1.710853 -1.449791 -0.244037
# 2013-04-10  0.604908 -0.421194 -0.256138  1.509580

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
gender_labels = np.random.choice(['Male', 'Female'], size=100)
df['F'] = gender_labels
print(df)
# Out:
#                    A         B         C         D       F
# 2013-01-01  0.439197  0.832251  0.243078 -1.511943  Female
# 2013-01-02  0.127782  1.163029  0.550664  2.425523    Male
# 2013-01-03  0.635652 -0.415797  0.156302  1.067944  Female
# 2013-01-04 -0.450968  1.995191 -0.372842 -0.437582  Female
# 2013-01-05  1.056763  0.787233  2.046163  0.462268    Male
# ...              ...       ...       ...       ...     ...
# 2013-04-06 -0.730466  0.222357 -0.974069 -0.838114    Male
# 2013-04-07 -0.214145 -0.093782  0.104368  0.825225    Male
# 2013-04-08  0.478841 -0.535936  0.341119 -0.368259    Male
# 2013-04-09 -0.080610 -0.664729  1.059279  0.484628  Female
# 2013-04-10  1.406997 -2.799906 -2.921888 -0.750109    Male
#
# [100 rows x 5 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.loc[:,'D']=np.array([5]*len(df))
print(df)
# Out:
#                    A         B         C    D
# 2013-01-01 -2.251516 -1.943758 -0.963479  5.0
# 2013-01-02 -0.250287  1.243332  0.650017  5.0
# 2013-01-03  0.148140 -2.230338 -0.142714  5.0
# 2013-01-04  0.133097 -1.698891  1.144655  5.0
# 2013-01-05 -0.655751 -0.485734 -2.518145  5.0
# ...              ...       ...       ...  ...
# 2013-04-06 -1.551319  0.643696 -0.139530  5.0
# 2013-04-07 -0.605530  0.206166  1.435599  5.0
# 2013-04-08  0.673723  0.395344  1.045237  5.0
# 2013-04-09 -1.313465  0.559547  0.860541  5.0
# 2013-04-10 -0.606602  1.656628  1.245840  5.0
#
# [100 rows x 4 columns]

# %%
import pandas as pd 
import numpy as np
dates=pd.date_range('20130101', periods=100)
df = pd.DataFrame(np.random.randn(100,4), index=dates, columns=list('ABCD'))
df.drop('A', axis =1, inplace=True)
print(df)
# Out:
#                    B         C         D
# 2013-01-01 -0.125586 -0.226167  0.731715
# 2013-01-02 -0.161393 -0.230115 -0.513087
# 2013-01-03  0.757369  0.090496  0.140952
# 2013-01-04  0.311539 -1.437591  1.070063
# 2013-01-05 -1.697505 -0.327406 -0.945238
# ...              ...       ...       ...
# 2013-04-06 -0.715504 -0.976489  0.049241
# 2013-04-07  1.568182 -0.815070 -0.071946
# 2013-04-08  1.339345  2.331459 -0.202019
# 2013-04-09  0.159623  0.823368  0.445627
# 2013-04-10 -1.632066 -1.057497  0.753699
#
# [100 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
 
df = pd.DataFrame({'Courses': ["GFG", "JS", "Python", "Numpy"],
                   'Fee': [20000, 25000, 22000, 24000]})
 
df1 = pd.DataFrame({'Courses': ["Matplotlib", "SSC", "CHSL", "Java"],
                    'Fee': [25000, 25200, 24500, 24900]})
 
df2 = pd.DataFrame({'Duration': ['30day', '40days', '35days', '60days'],
                    'Discount': [1000, 2300, 2500, 2000]})

# concatenating df1 and df2 along rows
vertical_concat = pd.concat([df, df1], axis=0)
 
# concatenating df3 and df4 along columns
horizontal_concat = pd.concat([df1, df2], axis=1)
 
print("Vertical:")
print(vertical_concat)
print("Horizontal:")
print(horizontal_concat)

#sorting and ordering a dataframe
df.sort_values(by='Fee')
# Out:
# Vertical:
#       Courses    Fee
# 0         GFG  20000
# 1          JS  25000
# 2      Python  22000
# 3       Numpy  24000
# 0  Matplotlib  25000
# 1         SSC  25200
# 2        CHSL  24500
# 3        Java  24900
# Horizontal:
#       Courses    Fee Duration  Discount
# 0  Matplotlib  25000    30day      1000
# 1         SSC  25200   40days      2300
# 2        CHSL  24500   35days      2500
# 3        Java  24900   60days      2000
#   Courses    Fee
# 0     GFG  20000
# 2  Python  22000
# 3   Numpy  24000
# 1      JS  25000

# %%
df = pd.read_csv('xyz.csv',header=None)
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
df = pd.read_csv('xyz.csv',header=None)
df.tail()
# Out:
#       0    1   2   3    4     5      6   7  8
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %%
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
print(df)
# Out:
#      preg  glu  bp  sft  ins   bmi    dpf  age  class
# 0       6  148  72   35    0  33.6  0.627   50      1
# 1       1   85  66   29    0  26.6  0.351   31      0
# 2       8  183  64    0    0  23.3  0.672   32      1
# 3       1   89  66   23   94  28.1  0.167   21      0
# 4       0  137  40   35  168  43.1  2.288   33      1
# ..    ...  ...  ..  ...  ...   ...    ...  ...    ...
# 763    10  101  76   48  180  32.9  0.171   63      0
# 764     2  122  70   27    0  36.8  0.340   27      0
# 765     5  121  72   23  112  26.2  0.245   30      0
# 766     1  126  60    0    0  30.1  0.349   47      1
# 767     1   93  70   31    0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
import matplotlib.pyplot as plt 
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
plt.scatter(df['bmi'],df['glu'])
plt.xlabel('bmi') 
plt.ylabel('Glucose')
# Out:
# Text(0, 0.5, 'Glucose')

# %%
import matplotlib.pyplot as plt 
df = pd.read_csv('xyz.csv',header=None)
df.columns=['preg','glu','bp','sft','ins','bmi','dpf','age','class']
df['age'].hist()
# Out:
# <Axes: >
